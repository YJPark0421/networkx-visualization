# %% [markdown]
# # Introduction to Networkx Layouts

# %%
import pandas as pd
import numpy as np
import datetime as dt

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
import networkx as nx
import pygraphviz
import warnings

# %matplotlib inline
plt.rc('axes', axisbelow=True)

# plt.rcParams['axes.unicode_minus'] = False
# plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['figure.facecolor'] = 'w'

# %% [markdown]
# # Visualization
# - [pygraphvizerror](https://pygraphviz.github.io/documentation/stable/install.html)
#
# ---
# **① Download and install 2.46.0 for Windows 10 (64-bit)**<br>
# stable_windows_10_cmake_Release_x64_graphviz-install-2.46.0-win64.exe
#
# **② Install PyGraphviz via**<br>
# pip install --global-option=build_ext --global-option="-IC:\Program Files\Graphviz\include" --global-option="-LC:\Program Files\Graphviz\lib" pygraphviz

# %% [markdown]
# ##### 1) Line Style

# %%
import pygraphviz

G = nx.path_graph(4)
pos = nx.nx_agraph.graphviz_layout(G, prog="dot")
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
pos = nx.kamada_kawai_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
pos = nx.spring_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
pos = nx.random_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %% [markdown]
# ##### 2) Curve style

# %%
G = nx.path_graph(4)
pos = nx.spiral_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
pos = nx.spiral_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %% [markdown]
# ##### 3) Triangle Style

# %%
G = nx.path_graph(4)
pos = nx.planar_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
shells = [[0], [1, 2, 3]]
pos = nx.shell_layout(G, shells)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %% [markdown]
# ##### 5) Ractangle Style

# %%
G = nx.path_graph(4)
pos = nx.circular_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
G = nx.path_graph(4)
pos = nx.spectral_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %% [markdown]
# ##### 6) Bipartite Style

# %%
G = nx.bipartite.gnmk_random_graph(3, 5, 10, seed=123)
top = nx.bipartite.sets(G)[0]
pos = nx.bipartite_layout(G, top)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
G = nx.complete_multipartite_graph(1, 3, 3, 3)
pos = nx.multipartite_layout(G)
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %% [markdown]
# # Converting to and from other data formats
# [from_pandas_edgelist](https://networkx.org/documentation/stable/reference/generated/networkx.convert_matrix.from_pandas_edgelist.html)

# %%
df = pd.DataFrame({ 'from':['D', 'A', 'B', 'C','A'], 'to':['A', 'D', 'A', 'E','C']})
G = nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

# %% [markdown]
# ---
# # 🔎 Reference
# - [NetworkX](https://networkx.org/documentation/stable/tutorial.html)
# - [Converting to and from other data formats
# To NetworkX Graph](https://networkx.org/documentation/stable/reference/convert.html#converting-to-and-from-other-data-formats)
